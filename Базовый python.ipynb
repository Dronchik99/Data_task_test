# %%
import pandas as pd
df = pd.read_csv('Desktop\тестна.csv', sep='\t', delimiter=';')
df2 = df.groupby(['Категория']).agg({
  'Продажи': 'nlargest',
}).reset_index()
df2.loc[:,'level_1']
df.iloc[df2.loc[:,'level_1']]
# Out:
#            Категория     Товар  Продажи  Возвраты
# 41  Air conditioners  85664378    98943       -70
# 46  Air conditioners  72985499    94800         0
# 47  Air conditioners  37110667    90051      -209
# 48  Air conditioners  52097804    89085         0
# 45  Air conditioners  90072851    88828      -489
# 64         Computers  97760955    93034         0
# 55         Computers  52628211    84085      -363
# 58         Computers  12467242    80341      -191
# 53         Computers  82661795    73281         0
# 54         Computers  58764689    67260         0
# 84   Gaming consoles  86887234    91082       -48
# 72   Gaming consoles  15092936    79276      -467
# 85   Gaming consoles  32659211    76672       -58
# 74   Gaming consoles  79850604    67586      -461
# 79   Gaming consoles  97745303    65142         0
# 35        Headphones  64334620    86733         0
# 33        Headphones  17707295    60326       -17
# 34        Headphones  61773308    52371      -217
# ...
